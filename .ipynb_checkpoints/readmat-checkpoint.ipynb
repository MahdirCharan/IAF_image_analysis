# %%
import pandas as pd
import scipy.io
import readmat

# %%
mat21 = readmat.load('Neutrophils_March3.mat', isStruct=True)

# %%
print(type(mat21))

# %%
df1 = pd.DataFrame(mat21.data1.x)

# %%
loc1 = mat21.data1.y
loc2 = mat21.data1.trId

# %%
df1[1] = loc1
df1[2] = loc2

# %%
df1

# %%
gb = df1.groupby(2)

# %%
gb.head()

# %%
ids = df1[2]

# %%
ids

# %%
id21 = df1[df1[2] == 21]

# %%
id21

# %%
id21.plot(x=0, y=1, style='o')

# %%
data = readmat.load('Jurkat\GC7 25-Nov-2020-20-17-20.mat', isStruct=True)

# %%
cols = data.cols
conc = data.conc
rows = data.rows
Zm = (1510236 + 7683.45 * conc) * 1e-6

# %%
df = pd.DataFrame(conc)

# %%
df['cols'] = cols
df['rows'] = rows
df['impedance'] = Zm
df['prefocusing'] = 'on'

# %%
df.rename({0: "conc"}, axis="columns")

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
ax = sns.violinplot(x=df["impedance"])

# %%
df

# %%
df.to_csv ('export_dataframe.csv', index = None, header=True)

# %%
data = pd.read_csv('export_dataframe.csv')

# %%
data.info()

# %%
tips = sns.load_dataset("tips")

# %%
tips

# %%
data1 = readmat.load('Jurkat\GC7 25-Nov-2020-20-17-20.mat', isStruct=True)
data2 = readmat.load('Jurkat\GC2 25-Nov-2020-20-03-38.mat', isStruct=True)

# %%
df1 = pd.DataFrame(
{
"conc": data1.conc,
"cols": data1.cols,
"rows": data1.rows,
"impedance": (1510236 + 7683.45 * data1.conc) * 1e-6,
"prefocusing": "Yes",
"cell": "Jurkat"
})
df2 = pd.DataFrame(
{
"conc": data2.conc,
"cols": data2.cols,
"rows": data2.rows,
"impedance": (1510236 + 7683.45 * data2.conc) * 1e-6,
"prefocusing": "No",
"cell": "Jurkat"
})

# %%
frames = [df1, df2]

# %%
result = pd.concat(frames, ignore_index=True)

# %%
result

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
ax = sns.violinplot(x="cell", y="impedance", hue="prefocusing",
                    data=result, palette="muted", split=True)

# %%
import pandas as pd
import scipy.io
import readmat

data1 = readmat.load('Jurkat_2.510_off.mat', isStruct=True)
data2 = readmat.load('Jurkat_2.510_on.mat', isStruct=True)

# %%
df1 = pd.DataFrame(
{
"conc": data1.conc,
"cols": data1.cols,
"rows": data1.rows,
"impedance": (1510236 + 7683.45 * data1.conc) * 1e-6,
"prefocusing": "No",
"cell": "Jurkat",
"Q": "2.5_10"
})

df2 = pd.DataFrame(
{
"conc": data2.conc,
"cols": data2.cols,
"rows": data2.rows,
"impedance": (1510236 + 7683.45 * data2.conc) * 1e-6,
"prefocusing": "Yes",
"cell": "Jurkat",
"Q": "2.5_10"
})

frames1 = [df1, df2]

result1 = pd.concat(frames1, ignore_index=True)
result1
# Out:
#            conc        cols         rows  impedance prefocusing    cell  \
# 0     13.360799  172.052632   273.652047   1.612893          No  Jurkat
# 1     16.505027  209.952454  1824.056748   1.637052          No  Jurkat
# 2     16.964617  214.563069  1058.397919   1.640583          No  Jurkat
# 3     17.102579  215.841530   710.990893   1.641643          No  Jurkat
# 4     17.027419  215.153846  1147.338942   1.641065          No  Jurkat
# ...         ...         ...          ...        ...         ...     ...
# 3510  17.015361  443.749515   320.244660   1.640973         Yes  Jurkat
# 3511  17.031072  443.549708  1340.304094   1.641093         Yes  Jurkat
# 3512  16.631166  447.819876  1438.515528   1.638021         Yes  Jurkat
# 3513  16.041254  454.268012  1754.642651   1.633488         Yes  Jurkat
# 3514  15.088570  465.424552  1229.593350   1.626168         Yes  Jurkat
#
#            Q
# 0     2.5_10
# 1     2.5_10
# 2     2.5_10
# 3     2.5_10
# 4     2.5_10
# ...      ...
# 3510  2.5_10
# 3511  2.5_10
# 3512  2.5_10
# 3513  2.5_10
# 3514  2.5_10
#
# [3515 rows x 7 columns]

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

ax = sns.violinplot(x="cell", y="impedance", hue="prefocusing",
                    data=result1, palette="muted", split=True)

# %%
data3 = readmat.load('Jurkat_2.515_off.mat', isStruct=True)
data4 = readmat.load('Jurkat_2.515_on.mat', isStruct=True)

# %%
df3 = pd.DataFrame(
{
"conc": data3.conc,
"cols": data3.cols,
"rows": data3.rows,
"impedance": (1510236 + 7683.45 * data3.conc) * 1e-6,
"prefocusing": "No",
"cell": "Jurkat",
"Q": "2.5_15"
})
df4 = pd.DataFrame(
{
"conc": data4.conc,
"cols": data4.cols,
"rows": data4.rows,
"impedance": (1510236 + 7683.45 * data4.conc) * 1e-6,
"prefocusing": "Yes",
"cell": "Jurkat",
"Q": "2.5_15"
})

frames2 = [df3, df4]

result2 = pd.concat(frames2, ignore_index=True)
result2
# Out:
#            conc        cols         rows  impedance prefocusing    cell  \
# 0     14.260852  221.115460  1358.174168   1.619809          No  Jurkat
# 1     14.461919  223.273723  1800.094891   1.621353          No  Jurkat
# 2     16.626778  243.998153   525.631773   1.637987          No  Jurkat
# 3     16.569428  243.507795  1189.675947   1.637546          No  Jurkat
# 4     17.804381  253.849964  1439.984925   1.647035          No  Jurkat
# ...         ...         ...          ...        ...         ...     ...
# 3855  15.737344  420.325635   209.766744   1.631153         Yes  Jurkat
# 3856  15.547467  422.073741  1297.208633   1.629694         Yes  Jurkat
# 3857  15.723125  420.464037  1662.767981   1.631044         Yes  Jurkat
# 3858  15.566826  421.895722  1732.446524   1.629843         Yes  Jurkat
# 3859  15.424498  423.264706   897.314480   1.628749         Yes  Jurkat
#
#            Q
# 0     2.5_15
# 1     2.5_15
# 2     2.5_15
# 3     2.5_15
# 4     2.5_15
# ...      ...
# 3855  2.5_15
# 3856  2.5_15
# 3857  2.5_15
# 3858  2.5_15
# 3859  2.5_15
#
# [3860 rows x 7 columns]

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

ax = sns.violinplot(x="cell", y="impedance", hue="prefocusing",
                    data=result2, palette="muted", split=True)

# %%
data5 = readmat.load('Jurkat_7.515_off.mat', isStruct=True)
data6 = readmat.load('Jurkat_7.515_on.mat', isStruct=True)

# %%
df5 = pd.DataFrame(
{
"conc": data5.conc,
"cols": data5.cols,
"rows": data5.rows,
"impedance": (1510236 + 7683.45 * data5.conc) * 1e-6,
"prefocusing": "No",
"cell": "Jurkat",
"Q": "7.5_15"
})
df6 = pd.DataFrame(
{
"conc": data6.conc,
"cols": data6.cols,
"rows": data6.rows,
"impedance": (1510236 + 7683.45 * data6.conc) * 1e-6,
"prefocusing": "Yes",
"cell": "Jurkat",
"Q": "7.5_15"
})

frames3 = [df5, df6]

result3 = pd.concat(frames3, ignore_index=True)
result3
# Out:
#            conc        cols         rows  impedance prefocusing    cell  \
# 0     13.264445   94.640587   210.141809   1.612153          No  Jurkat
# 1     16.216834  132.998985  1314.122843   1.634837          No  Jurkat
# 2     15.839041  129.260148  1044.285978   1.631934          No  Jurkat
# 3     17.586501  145.131496   776.751969   1.645361          No  Jurkat
# 4     17.374919  143.426887  1685.936321   1.643735          No  Jurkat
# ...         ...         ...          ...        ...         ...     ...
# 2530  16.182606  530.510791   889.069544   1.634574         Yes  Jurkat
# 2531  15.505743  537.945055   446.734432   1.629374         Yes  Jurkat
# 2532  15.671102  535.920375   556.918033   1.630644         Yes  Jurkat
# 2533  14.153432  555.333333  1205.094624   1.618983         Yes  Jurkat
# 2534  13.798449  560.972892   221.855422   1.616256         Yes  Jurkat
#
#            Q
# 0     7.5_15
# 1     7.5_15
# 2     7.5_15
# 3     7.5_15
# 4     7.5_15
# ...      ...
# 2530  7.5_15
# 2531  7.5_15
# 2532  7.5_15
# 2533  7.5_15
# 2534  7.5_15
#
# [2535 rows x 7 columns]

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

ax = sns.violinplot(x="cell", y="impedance", hue="prefocusing",
                    data=result3, palette="muted", split=True)

# %%
tot_frames = [df1, df2, df3, df4, df5, df6]
tot_result = pd.concat(tot_frames, ignore_index=True)
tot_result
# Out:
#            conc        cols         rows  impedance prefocusing    cell  \
# 0     13.360799  172.052632   273.652047   1.612893          No  Jurkat
# 1     16.505027  209.952454  1824.056748   1.637052          No  Jurkat
# 2     16.964617  214.563069  1058.397919   1.640583          No  Jurkat
# 3     17.102579  215.841530   710.990893   1.641643          No  Jurkat
# 4     17.027419  215.153846  1147.338942   1.641065          No  Jurkat
# ...         ...         ...          ...        ...         ...     ...
# 9905  16.182606  530.510791   889.069544   1.634574         Yes  Jurkat
# 9906  15.505743  537.945055   446.734432   1.629374         Yes  Jurkat
# 9907  15.671102  535.920375   556.918033   1.630644         Yes  Jurkat
# 9908  14.153432  555.333333  1205.094624   1.618983         Yes  Jurkat
# 9909  13.798449  560.972892   221.855422   1.616256         Yes  Jurkat
#
#            Q
# 0     2.5_10
# 1     2.5_10
# 2     2.5_10
# 3     2.5_10
# 4     2.5_10
# ...      ...
# 9905  7.5_15
# 9906  7.5_15
# 9907  7.5_15
# 9908  7.5_15
# 9909  7.5_15
#
# [9910 rows x 7 columns]

# %%
ax = sns.violinplot(x="Q", y="impedance", hue="prefocusing",
                    data=tot_result, palette="muted", split=True)

# %%
datal = readmat.load('Jurkat_N_Q7.515_off.mat', isStruct=True)
data2 = readmat.load('Jurkat_N_Q7.515_on.mat', isStruct=True)
data3 = readmat.load('Jurkat_N_Q7.520_off.mat', isStruct=True)
data4 = readmat.load('Jurkat_N_Q7.520_on.mat', isStruct=True)
data5 = readmat.load('Jurkat_N_Q7.525_off.mat', isStruct=True)
data6 = readmat.load('Jurkat_N_Q7.525_on.mat', isStruct=True)

# %%
df1 = pd.DataFrame(
{
"conc": data1.conc,
"cols": data1.cols,
"rows": data1.rows,
"impedance": (1510236 + 7683.45 * data1.conc) * 1e-6,
"prefocusing": "No",
"cell": "Jurkat",
"Qcenter = 7.5 μl/min": "Qside = 15 μl/min"
})
df2 = pd.DataFrame(
{
"conc": data2.conc,
"cols": data2.cols,
"rows": data2.rows,
"impedance": (1510236 + 7683.45 * data2.conc) * 1e-6,
"prefocusing": "Yes",
"cell": "Jurkat",
"Qcenter = 7.5 μl/min": "Qside = 15 μl/min"
})
df3 = pd.DataFrame(
{
"conc": data3.conc,
"cols": data3.cols,
"rows": data3.rows,
"impedance": (1510236 + 7683.45 * data3.conc) * 1e-6,
"prefocusing": "No",
"cell": "Jurkat",
"Qcenter = 7.5 μl/min": "Qside = 20 μl/min"
})
df4 = pd.DataFrame(
{
"conc": data4.conc,
"cols": data4.cols,
"rows": data4.rows,
"impedance": (1510236 + 7683.45 * data4.conc) * 1e-6,
"prefocusing": "Yes",
"cell": "Jurkat",
"Qcenter = 7.5 μl/min": "Qside = 20 μl/min"
})

df5 = pd.DataFrame(
{
"conc": data5.conc,
"cols": data5.cols,
"rows": data5.rows,
"impedance": (1510236 + 7683.45 * data5.conc) * 1e-6,
"prefocusing": "No",
"cell": "Jurkat",
"Qcenter = 7.5 μl/min": "Qside = 25 μl/min"
})

df6 = pd.DataFrame(
{
"conc": data6.conc,
"cols": data6.cols,
"rows": data6.rows,
"impedance": (1510236 + 7683.45 * data6.conc) * 1e-6,
"prefocusing": "Yes",
"cell": "Jurkat",
"Qcenter = 7.5 μl/min": "Qside = 25 μl/min"
})

frames = [df1, df2, df3, df4, df5, df6]

result = pd.concat(frames, ignore_index=True)
result
# Out:
#            conc        cols         rows  impedance prefocusing    cell  \
# 0     13.360799  172.052632   273.652047   1.612893          No  Jurkat
# 1     16.505027  209.952454  1824.056748   1.637052          No  Jurkat
# 2     16.964617  214.563069  1058.397919   1.640583          No  Jurkat
# 3     17.102579  215.841530   710.990893   1.641643          No  Jurkat
# 4     17.027419  215.153846  1147.338942   1.641065          No  Jurkat
# ...         ...         ...          ...        ...         ...     ...
# 5125  12.794013  499.799026   786.986697   1.608538         Yes  Jurkat
# 5126  12.417721  504.985239  1048.684823   1.605647         Yes  Jurkat
# 5127  12.369456  505.640975  1305.181750   1.605276         Yes  Jurkat
# 5128  12.565277  502.936531  1815.858438   1.606781         Yes  Jurkat
# 5129  11.896475  512.789416   460.658394   1.601642         Yes  Jurkat
#
#      Qcenter = 7.5 μl/min
# 0       Qside = 15 μl/min
# 1       Qside = 15 μl/min
# 2       Qside = 15 μl/min
# 3       Qside = 15 μl/min
# 4       Qside = 15 μl/min
# ...                   ...
# 5125    Qside = 25 μl/min
# 5126    Qside = 25 μl/min
# 5127    Qside = 25 μl/min
# 5128    Qside = 25 μl/min
# 5129    Qside = 25 μl/min
#
# [5130 rows x 7 columns]

# %%
result.to_csv ('violin_plot.csv', index = None, header=True)

# %%
ax = sns.violinplot(x="Qcenter = 7.5 μl/min", y="impedance", hue="prefocusing",
                    data=result, palette="muted", split=True, inner="quartile")
ax.set_title("Distribution of impedance for Jurkat cells");

# %%
hist1 = sns.displot(result, x="cols", hue="Qcenter = 7.5 μl/min",kind="kde", multiple="stack")

# %%
result1 = result[result["prefocusing"]=="Yes"]
result1
# Out:
#            conc        cols         rows  impedance prefocusing    cell  \
# 1689  14.516753   86.778519  1897.677184   1.621775         Yes  Jurkat
# 1690  16.237064  114.384391  1179.803768   1.634993         Yes  Jurkat
# 1691  16.316298  115.217121   897.517510   1.635601         Yes  Jurkat
# 1692  14.970339   95.433155   466.840463   1.625260         Yes  Jurkat
# 1693  14.440397   85.150479  1548.357045   1.621188         Yes  Jurkat
# ...         ...         ...          ...        ...         ...     ...
# 5125  12.794013  499.799026   786.986697   1.608538         Yes  Jurkat
# 5126  12.417721  504.985239  1048.684823   1.605647         Yes  Jurkat
# 5127  12.369456  505.640975  1305.181750   1.605276         Yes  Jurkat
# 5128  12.565277  502.936531  1815.858438   1.606781         Yes  Jurkat
# 5129  11.896475  512.789416   460.658394   1.601642         Yes  Jurkat
#
#      Qcenter = 7.5 μl/min
# 1689    Qside = 15 μl/min
# 1690    Qside = 15 μl/min
# 1691    Qside = 15 μl/min
# 1692    Qside = 15 μl/min
# 1693    Qside = 15 μl/min
# ...                   ...
# 5125    Qside = 25 μl/min
# 5126    Qside = 25 μl/min
# 5127    Qside = 25 μl/min
# 5128    Qside = 25 μl/min
# 5129    Qside = 25 μl/min
#
# [1896 rows x 7 columns]

# %%
hist2 = sns.displot(result1, x="cols", hue="Qcenter = 7.5 μl/min",kind="kde", multiple="stack")
hist2.set(xlabel="Width of the channel");
